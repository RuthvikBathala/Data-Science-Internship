# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

df = pd.read_csv('T20 International Dataset.csv')
df
# Out:
#         Unnamed: 0  powerPlay  AverageScore   battingTeam   bowlingTeam  \
# 0            32266          0    153.142857   New Zealand     Sri Lanka
# 1            47001          0    158.307692       England  South Africa
# 2            45705          0    158.307692   New Zealand  South Africa
# 3            59293          1    149.000000  South Africa   New Zealand
# 4           174494          0    137.000000      Pakistan     Sri Lanka
# ...            ...        ...           ...           ...           ...
# 131619      104582          0    149.275862         India   New Zealand
# 131620       50938          0    168.666667      Pakistan   New Zealand
# 131621       80339          0    130.714286      Zimbabwe  South Africa
# 131622       99444          0    128.395349      Pakistan       England
# 131623      121673          1    135.609756         India     Sri Lanka
#
#                 city  delivery_left  score  CurrentRunRate  wicketsLeft  \
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
index_names = df[ df['innings'] == 2 ].index
  
df.drop(index_names, inplace = True)
df.drop(['powerPlay','innings'],axis=1,inplace=True)
df
# Out:
#         AverageScore   battingTeam   bowlingTeam             city  \
# 0         153.142857   New Zealand     Sri Lanka          Colombo
# 1         158.307692       England  South Africa           Durban
# 2         158.307692   New Zealand  South Africa           Durban
# 3         149.000000  South Africa   New Zealand       Chattogram
# 8         157.214286      Pakistan     Australia           Harare
# ...              ...           ...           ...              ...
# 131616    153.882353  South Africa   New Zealand         Barbados
# 131617    169.222222   New Zealand    Bangladesh  Mount Maunganui
# 131618    152.800000  South Africa   New Zealand           London
# 131620    168.666667      Pakistan   New Zealand         Auckland
# 131621    130.714286      Zimbabwe  South Africa       Hambantota
#
#         delivery_left  score  CurrentRunRate  wicketsLeft  Run_In_Last5  \
# 0                  51     94        8.173913            9          42.0
# ...

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (55973, 10) (55973,)
# (13994, 10) (13994,)

# %%
# !pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/99.8 MB 6.4 MB/s eta 0:00:16
#    ---------------------------------------- 0.3/99.8 MB 3.9 MB/s eta 0:00:26
#    ---------------------------------------- 0.5/99.8 MB 4.0 MB/s eta 0:00:25
#    ---------------------------------------- 0.6/99.8 MB 4.1 MB/s eta 0:00:24
#    ---------------------------------------- 0.8/99.8 MB 4.3 MB/s eta 0:00:23
#    ---------------------------------------- 1.2/99.8 MB 5.0 MB/s eta 0:00:20
#     --------------------------------------- 1.4/99.8 MB 5.3 MB/s eta 0:00:19
#     --------------------------------------- 1.8/99.8 MB 5.7 MB/s eta 0:00:18
#     --------------------------------------- 2.2/99.8 MB 6.0 MB/s eta 0:00:17
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['battingTeam','bowlingTeam','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\RUTHVIK\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9889258655502066
# 1.651907412583647

# %%
import pickle
pickle.dump(pipe,open(r"C:\Users\RUTHVIK\Desktop\internship\Innomatics proj\Productionize a ML Model\pipe.pkl",'wb'))
